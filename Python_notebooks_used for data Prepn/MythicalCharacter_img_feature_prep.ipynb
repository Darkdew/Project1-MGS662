# %%
# example of loading an image with the Keras API
from keras.preprocessing.image import load_img
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img
import pandas as pd

# %%
# load the excel sheet with file names of each of the image file
#class_1
df_mythchar_class1= pd.read_excel('/content/drive/MyDrive/Project1/train_mythchar/mythchar_Class_1.xlsx')

#creating a list to store all 75 features for all the files in this class
listFinal=[]

#looping on all the rows of the file names in the class1 category 
for i in range(len(df_mythchar_class1)):
  list1=[]
  
  #parameterizing the location of each file with its unique name
  a=str('/content/drive/MyDrive/Project1/train_mythchar/Class_1/')
  b= str(df_mythchar_class1.iloc[i, 0])
  file_loc_str=  a+b

  #loading each of the image in the loop one at a time
  img = load_img(path=file_loc_str, target_size=(5,5))
  
  # converting this img to array
  img_array = img_to_array(img)

  #reshaping the 3 channel img_array to 1 dimension with 5*5*3
  reshaped_array= img_array.reshape(1,75)
  
  #converting the array to a list and appending to a final list
  list1= list(reshaped_array[0])
  
  listFinal.append(list1)


  #defining column names for each of the 75 features extracted
column_list=[]
for k in range(1,76):
  col_name= "feature"+ str(k)
  column_list.append(col_name)

print(len(column_list))


#defining a new features dataframe with each of the 75 features
#of a particular image as rows
df_features= pd.DataFrame(listFinal, columns=column_list )

#lets check out what we got
df_features.head()
# Out:
# 75
#    feature1  feature2  feature3  ...  feature73  feature74  feature75
# 0     179.0     164.0     157.0  ...      180.0      176.0      173.0
# 1     223.0     111.0      35.0  ...      144.0      145.0      137.0
# 2       0.0       1.0       0.0  ...      104.0      106.0       85.0
# 3     177.0     133.0      98.0  ...       67.0       73.0       73.0
# 4      34.0      30.0       1.0  ...       53.0       41.0        0.0
#
# [5 rows x 75 columns]

# %%
#creating a new list of all the filenames in class1
File_name_list= list(df_mythchar_class1.iloc[:, 0])

#inserting the File_name_list as column0 in the df_features dataframe
df_features.insert(loc=0, column= "FileName", value= File_name_list )

#inserting the label column with class 1
label_list= []
for values in range(len(df_features)):
  label_list.append(1)

df_features.insert(loc=76, column= "Class_label", value= label_list )

df_features.tail()
# Out:
#                      FileName  feature1  ...  feature75  Class_label
# 69  32_chandimangal_part1.jpg     167.0  ...       75.0            1
# 70  32_chandimangal_part7.jpg     248.0  ...       51.0            1
# 71  32_chandimangal_part8.jpg     225.0  ...       38.0            1
# 72            35_shotopir.jpg     191.0  ...       38.0            1
# 73      35_shotopir_part1.jpg     165.0  ...      100.0            1
#
# [5 rows x 77 columns]

# %% [markdown]
# #Processing images belonging to mythchar class0

# %%
# load the excel sheet with file names of each of the image file
#class_0
df_mythchar_class0= pd.read_excel('/content/drive/MyDrive/Project1/train_mythchar/mythchar_Class_0.xlsx')

#creating a list to store all 75 features for all the files in this class
listFinal=[]

#looping on all the rows of the file names in the class1 category 
for i in range(len(df_mythchar_class0)):
  list1=[]
  
  #parameterizing the location of each file with its unique name
  a=str('/content/drive/MyDrive/Project1/train_mythchar/Class_0/')
  b= str(df_mythchar_class0.iloc[i, 0])
  file_loc_str=  a+b

  #loading each of the image in the loop one at a time
  img = load_img(path=file_loc_str, target_size=(5,5))
  
  # converting this img to array
  img_array = img_to_array(img)

  #reshaping the 3 channel img_array to 1 dimension with 5*5*3
  reshaped_array= img_array.reshape(1,75)
  
  #converting the array to a list and appending to a final list
  list1= list(reshaped_array[0])
  
  listFinal.append(list1)


#defining column names for each of the 75 features extracted
column_list=[]
for k in range(1,76):
  col_name= "feature"+ str(k)
  column_list.append(col_name)


#defining a new features dataframe with each of the 75 features
#of a particular image as rows
df_features_0= pd.DataFrame(listFinal, columns=column_list )

#creating a new list of all the filenames in class0
File_name_list= list(df_mythchar_class0.iloc[:, 0])

#inserting the File_name_list as column0 in the df_features dataframe

df_features_0.insert(loc=0, column= "FileName", value= File_name_list )


#lets see how our extracted features along with respective file names looks
df_features_0.head()


#inserting the label column with class 0
label_list= []
for values in range(len(df_features_0)):
  label_list.append(0)

df_features_0.insert(loc=76, column= "Class_label", value= label_list )

#lets see how our extracted features along with respective file names looks
df_features_0.head()
# Out:
#                 FileName  feature1  feature2  ...  feature74  feature75  Class_label
# 0  01_binladen_part3.jpg      76.0      68.0  ...       70.0       29.0            0
# 1  01_binladen_part4.jpg      83.0      40.0  ...       43.0       36.0            0
# 2  01_binladen_part5.jpg     207.0     202.0  ...      226.0      208.0            0
# 3    03_manasa_part1.jpg      47.0      70.0  ...      128.0       58.0            0
# 4    03_manasa_part2.jpg     158.0     133.0  ...       29.0       31.0            0
#
# [5 rows x 77 columns]

# %%
df_features_0.shape
# Out:
# (129, 77)

# %%
#appending the 2 dataframes vertically
#this will give us the complete dataset of mythchars data with file name, 75 features and respective label
df_img_features=df_features.append(df_features_0, ignore_index=True)

#lets export this data to an excel file
df_img_features.to_excel(r'/content/drive/MyDrive/Project1/train_mythchar/mythchar_imagefeatures.xlsx', index = False)

# %%
df_img_features.shape
# Out:
# (203, 77)
